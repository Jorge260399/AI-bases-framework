# %% [markdown]
# # **Librerías**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import time
from sklearn import svm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # **Cargar el dataset**

# %%
data = pd.read_csv('Banana_Ripeness_Dataset.csv')

df = pd.DataFrame(data)

df.head(15)
# Out:
#     SampleID           R           G          B   view            class
# 0          1  128.387045  148.385068  88.125925  front      light green
# 1          2   91.396778  114.322955  48.277243  front            green
# 2          3   87.804595  112.774147  50.034383  front            green
# 3          4   81.901377  103.886640  37.110752  front      light green
# 4          5   94.311041  120.103604  56.237598  front            green
# 5          6   76.520608  102.599004  41.981733  front      light green
# 6          7   93.302772  116.598634  53.715915  front            green
# 7          8   89.898268  109.027225  52.059142  front      light green
# 8          9   86.832690  113.458006  49.634117  front      light green
# 9         10   89.010214  113.309468  52.686793  front      light green
# 10        11   95.521500  118.837084  64.085791  front      light green
# 11        12  104.146886  126.792587  68.251672  front      light green
# ...

# %% [markdown]
# # **Verificar y limpiar de datos**

# %%
df = df.drop(['view', 'SampleID'], axis=1)
df.head(15)
# Out:
#              R           G          B            class
# 0   128.387045  148.385068  88.125925      light green
# 1    91.396778  114.322955  48.277243            green
# 2    87.804595  112.774147  50.034383            green
# 3    81.901377  103.886640  37.110752      light green
# 4    94.311041  120.103604  56.237598            green
# 5    76.520608  102.599004  41.981733      light green
# 6    93.302772  116.598634  53.715915            green
# 7    89.898268  109.027225  52.059142      light green
# 8    86.832690  113.458006  49.634117      light green
# 9    89.010214  113.309468  52.686793      light green
# 10   95.521500  118.837084  64.085791      light green
# 11  104.146886  126.792587  68.251672      light green
# 12  102.007647  121.773805  58.496483  yellowish green
# 13   84.487086  103.033309  41.137988  yellowish green
# 14   83.640275  104.932365  41.334193  yellowish green

# %% [markdown]
# # **Identificar X y Y**

# %%
x= df.drop(['class'], axis=1)
y= df['class']

# %% [markdown]
# # **Ingeniería de características**

# %% [markdown]
# ### **Label Encoding**

# %%
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(y)
Y = pd.DataFrame(integer_encoded, columns=["class"])
Y.head(15)
# Out:
#     class
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       1
# 6       0
# 7       1
# 8       1
# 9       1
# 10      1
# 11      1
# 12      2
# 13      2
# 14      2

# %% [markdown]
# ### **Normalización**

# %%
scaler_mean = StandardScaler(with_mean=True, with_std=False)


scaler_minmax = RobustScaler(with_centering=False,
                             with_scaling=True,
                             quantile_range=(0, 100))
scaler_mean.fit(x)
scaler_minmax.fit(x.values)

# transform train and test sets
X_scaled = scaler_minmax.transform(scaler_mean.transform(x))

# %%
X_scaled = pd.DataFrame(X_scaled, columns=x.columns)

# %%
np.round(x.describe(), 1)
# Out:
#             R       G       B
# count  1164.0  1164.0  1164.0
# mean     80.9   101.8    45.1
# std      17.5    16.6    14.1
# min      29.3    50.5     9.0
# 25%      68.7    90.8    35.0
# 50%      81.0   102.7    44.2
# 75%      92.7   113.7    54.6
# max     136.6   155.4    98.8

# %%
np.round(X_scaled.describe(), 1)
# Out:
#             R       G       B
# count  1164.0  1164.0  1164.0
# mean     -0.0    -0.0     0.0
# std       0.2     0.2     0.2
# min      -0.5    -0.5    -0.4
# 25%      -0.1    -0.1    -0.1
# 50%       0.0     0.0    -0.0
# 75%       0.1     0.1     0.1
# max       0.5     0.5     0.6

# %% [markdown]
# # **Training and Testing**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y.values.reshape(-1,1),
                                        test_size   = 0.2,
                                        random_state = 1234,
                                        shuffle      = True)

X_train.shape, X_test.shape
# Out:
# ((931, 3), (233, 3))

# %% [markdown]
# # **Grid Search**

# %%
param_grid = [
    {
        "kernel": ["linear"],
		    "C": [0.0001, 0.001, 0.1, 1, 10, 100, 1000],
        "decision_function_shape": ['ovo', 'ovr']
    },
    {
        "kernel": ["poly"],
        "gamma": [1,0.1,0.01,0.001],
		    "degree": [2, 3, 4],
		    "C": [0.0001, 0.001, 0.1, 1, 10, 100, 1000],
        "decision_function_shape": ['ovo', 'ovr']
     
    },
	  {
        "kernel": ["rbf", "sigmoid"],
		    "gamma": [1,0.1,0.01,0.001],
		    "C": [0.0001, 0.001, 0.1, 1, 10, 100, 1000],
        "decision_function_shape": ['ovo', 'ovr']
    }
]

# %%
grid = GridSearchCV(estimator=svm.SVC(), param_grid=param_grid, refit=True, verbose=2)
start = time.time()
grid.fit(X_train, y_train.ravel())
end = time.time()
# Out:
# Fitting 5 folds for each of 294 candidates, totalling 1470 fits
# [CV] END C=0.0001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovr, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovr, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovr, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovr, kernel=linear; total time=   0.0s
# [CV] END C=0.0001, decision_function_shape=ovr, kernel=linear; total time=   0.0s
# [CV] END C=0.001, decision_function_shape=ovo, kernel=linear; total time=   0.0s
# ...

# %%
print("[INFO] grid search tardó {:.2f} segundos".format(
	end - start))
print("[INFO] El mejor puntaje de grid search es: {:.2f}%".format(
	grid.best_score_ * 100))
print("[INFO] Los mejores parametros de grid search son: {}".format(
	grid.best_params_))
# Out:
# [INFO] grid search tardó 66.25 segundos
# [INFO] El mejor puntaje de grid search es: 53.92%
# [INFO] Los mejores parametros de grid search son: {'C': 100, 'decision_function_shape': 'ovo', 'kernel': 'linear'}

# %% [markdown]
# # **SVM Model**

# %%
linear = svm.SVC(C=100, decision_function_shape='ovo', kernel='linear').fit(X_train, y_train.ravel())
rbf = svm.SVC(kernel='rbf', gamma=0.01, C=1000).fit(X_train, y_train.ravel())
poly = svm.SVC(decision_function_shape='ovo',kernel='poly', degree=3, C=1000).fit(X_train, y_train.ravel())
sigmoid = svm.SVC(kernel='sigmoid', gamma=0.1, C=100).fit(X_train, y_train.ravel())

# %%
linear_pred = linear.predict(X_test)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
sigmoid_pred = sigmoid.predict(X_test)

# %% [markdown]
# # **Model Evaluation**

# %%
confMatrix = confusion_matrix(y_test, linear_pred)

ax = sn.heatmap(confMatrix , annot=True)

ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")
plt.show()

# %%
linear_accuracy = accuracy_score(y_test, linear_pred)
linear_precision = precision_score(y_test, linear_pred, average='weighted')
linear_recall = recall_score(y_test, linear_pred, average='weighted')
linear_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (Linear Kernel): ', "%.2f" % (linear_accuracy*100))
print('F1 (Linear Kernel): ', "%.2f" % (linear_f1*100))
print('Precision (Linear Kernel): ', "%.2f" % (linear_precision*100))
print('Recall (Linear Kernel): ', "%.2f" % (linear_recall*100))
# Out:
# Accuracy (Linear Kernel):  51.50
# F1 (Linear Kernel):  51.51
# Precision (Linear Kernel):  52.19
# Recall (Linear Kernel):  51.50

# %%
confMatrix = confusion_matrix(y_test, poly_pred)

ax = sn.heatmap(confMatrix , annot=True)

ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")
plt.show()

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_precision = precision_score(y_test, poly_pred, average='weighted')
poly_recall = recall_score(y_test, poly_pred, average='weighted')
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
print('Precision (Polynomial Kernel): ', "%.2f" % (poly_precision*100))
print('Recall (Polynomial Kernel): ', "%.2f" % (poly_recall*100))
# Out:
# Accuracy (Polynomial Kernel):  56.65
# F1 (Polynomial Kernel):  53.41
# Precision (Polynomial Kernel):  66.71
# Recall (Polynomial Kernel):  56.65

# %%
confMatrix = confusion_matrix(y_test, rbf_pred)

ax = sn.heatmap(confMatrix , annot=True)

ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")
plt.show()

# %%
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_precision = precision_score(y_test, rbf_pred, average='weighted')
rbf_recall = recall_score(y_test, rbf_pred, average='weighted')
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
print('Precision (RBF Kernel): ', "%.2f" % (rbf_precision*100))
print('Recall (RBF Kernel): ', "%.2f" % (rbf_recall*100))
# Out:
# Accuracy (RBF Kernel):  53.22
# F1 (RBF Kernel):  53.11
# Precision (RBF Kernel):  54.00
# Recall (RBF Kernel):  53.22

# %%
confMatrix = confusion_matrix(y_test, sigmoid_pred)

ax = sn.heatmap(confMatrix , annot=True)

ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")
plt.show()

# %%
sigmoid_accuracy = accuracy_score(y_test, sigmoid_pred)
sigmoid_precision = precision_score(y_test, sigmoid_pred, average='weighted')
sigmoid_recall = recall_score(y_test, sigmoid_pred, average='weighted')
sigmoid_f1 = f1_score(y_test, sigmoid_pred, average='weighted')
print('Accuracy (Sigmoid Kernel): ', "%.2f" % (sigmoid_accuracy*100))
print('F1 (Sigmoid Kernel): ', "%.2f" % (sigmoid_f1*100))
print('Precision (Sigmoid Kernel): ', "%.2f" % (sigmoid_precision*100))
print('Recall (Sigmoid Kernel): ', "%.2f" % (sigmoid_recall*100))
# Out:
# Accuracy (Sigmoid Kernel):  53.65
# F1 (Sigmoid Kernel):  53.61
# Precision (Sigmoid Kernel):  54.43
# Recall (Sigmoid Kernel):  53.65

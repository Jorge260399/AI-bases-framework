# %% [markdown]
# # **Libraries**

# %%
import cv2
import os
import numpy as np
import glob
from sklearn.preprocessing import MinMaxScaler
import h5py
import mahotas as mt

# %% [markdown]
# # **Extracting Textural Features**

# %%
images_path = "./Banana_Ripeness_Dataset_RemovedBG"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['totally_green', 'yellow_with_brown_spots', 'yellow_with_green_tips']

# %%
def extract_features(image):
	# calculate haralick texture features for 4 types of adjacency
	textures = mt.features.haralick(image)

	# take the mean of it and return it
	ht_mean  = textures.mean(axis=0)
	return ht_mean

# %%
textural_features = []
textural_features_labels   = []

# %%
print("[STATUS] Started extracting haralick textures..")
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1

    for file in glob.glob(cur_path + "/*.png"):
        print("Processing Image - {} in {}".format(i, cur_label))
        # read the training image
        image = cv2.imread(file)

        # convert the image to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # extract haralick texture from the image
        features = extract_features(gray)

        # append the feature vector and label
        textural_features.append(features)
        textural_features_labels.append(cur_label)

        # show loop update
        i += 1
# Out:
# [STATUS] Started extracting haralick textures..
# Processing Image - 1 in totally_green
# Processing Image - 2 in totally_green
# Processing Image - 3 in totally_green
# Processing Image - 4 in totally_green
# Processing Image - 5 in totally_green
# Processing Image - 6 in totally_green
# Processing Image - 7 in totally_green
# Processing Image - 8 in totally_green
# Processing Image - 9 in totally_green
# Processing Image - 10 in totally_green
# Processing Image - 11 in totally_green
# Processing Image - 12 in totally_green
# Processing Image - 13 in totally_green
# Processing Image - 14 in totally_green
# Processing Image - 15 in totally_green
# Processing Image - 16 in totally_green
# Processing Image - 17 in totally_green
# Processing Image - 18 in totally_green
# Processing Image - 19 in totally_green
# Processing Image - 20 in totally_green
# Processing Image - 21 in totally_green
# Processing Image - 22 in totally_green
# Processing Image - 23 in totally_green
# Processing Image - 24 in totally_green
# Processing Image - 25 in totally_green
# Processing Image - 26 in totally_green
# Processing Image - 27 in totally_green
# Processing Image - 28 in totally_green
# Processing Image - 29 in totally_green
# Processing Image - 30 in totally_green
# Processing Image - 31 in totally_green
# Processing Image - 32 in totally_green
# Processing Image - 33 in totally_green
# Processing Image - 34 in totally_green
# Processing Image - 35 in totally_green
# Processing Image - 36 in totally_green
# Processing Image - 37 in totally_green
# Processing Image - 38 in totally_green
# Processing Image - 39 in totally_green
# Processing Image - 40 in totally_green
# Processing Image - 41 in totally_green
# Processing Image - 42 in totally_green
# Processing Image - 43 in totally_green
# Processing Image - 44 in totally_green
# Processing Image - 45 in totally_green
# Processing Image - 46 in totally_green
# Processing Image - 47 in totally_green
# Processing Image - 48 in totally_green
# Processing Image - 49 in totally_green
# Processing Image - 50 in totally_green
# Processing Image - 51 in totally_green
# Processing Image - 52 in totally_green
# Processing Image - 53 in totally_green
# Processing Image - 54 in totally_green
# Processing Image - 55 in totally_green
# Processing Image - 56 in totally_green
# Processing Image - 57 in totally_green
# Processing Image - 58 in totally_green
# Processing Image - 59 in totally_green
# Processing Image - 60 in totally_green
# Processing Image - 61 in totally_green
# Processing Image - 62 in totally_green
# Processing Image - 63 in totally_green
# Processing Image - 64 in totally_green
# Processing Image - 65 in totally_green
# Processing Image - 66 in totally_green
# Processing Image - 67 in totally_green
# Processing Image - 68 in totally_green
# Processing Image - 69 in totally_green
# Processing Image - 70 in totally_green
# Processing Image - 71 in totally_green
# Processing Image - 72 in totally_green
# Processing Image - 73 in totally_green
# Processing Image - 74 in totally_green
# Processing Image - 75 in totally_green
# Processing Image - 76 in totally_green
# Processing Image - 77 in totally_green
# Processing Image - 78 in totally_green
# Processing Image - 79 in totally_green
# Processing Image - 80 in totally_green
# Processing Image - 81 in totally_green
# Processing Image - 82 in totally_green
# Processing Image - 83 in totally_green
# Processing Image - 84 in totally_green
# Processing Image - 85 in totally_green
# Processing Image - 86 in totally_green
# Processing Image - 87 in totally_green
# Processing Image - 88 in totally_green
# Processing Image - 89 in totally_green
# Processing Image - 90 in totally_green
# Processing Image - 91 in totally_green
# Processing Image - 92 in totally_green
# Processing Image - 93 in totally_green
# Processing Image - 94 in totally_green
# Processing Image - 95 in totally_green
# Processing Image - 96 in totally_green
# Processing Image - 97 in totally_green
# Processing Image - 98 in totally_green
# Processing Image - 99 in totally_green
# Processing Image - 100 in totally_green
# Processing Image - 101 in totally_green
# Processing Image - 102 in totally_green
# Processing Image - 103 in totally_green
# Processing Image - 104 in totally_green
# Processing Image - 105 in totally_green
# Processing Image - 106 in totally_green
# Processing Image - 107 in totally_green
# Processing Image - 108 in totally_green
# Processing Image - 109 in totally_green
# Processing Image - 110 in totally_green
# Processing Image - 111 in totally_green
# Processing Image - 112 in totally_green
# Processing Image - 113 in totally_green
# Processing Image - 114 in totally_green
# Processing Image - 115 in totally_green
# Processing Image - 116 in totally_green
# Processing Image - 117 in totally_green
# Processing Image - 118 in totally_green
# Processing Image - 119 in totally_green
# Processing Image - 120 in totally_green
# Processing Image - 121 in totally_green
# Processing Image - 122 in totally_green
# Processing Image - 123 in totally_green
# Processing Image - 124 in totally_green
# Processing Image - 125 in totally_green
# Processing Image - 126 in totally_green
# Processing Image - 127 in totally_green
# Processing Image - 128 in totally_green
# Processing Image - 129 in totally_green
# Processing Image - 130 in totally_green
# Processing Image - 131 in totally_green
# Processing Image - 132 in totally_green
# Processing Image - 133 in totally_green
# Processing Image - 134 in totally_green
# Processing Image - 135 in totally_green
# Processing Image - 136 in totally_green
# Processing Image - 137 in totally_green
# Processing Image - 138 in totally_green
# Processing Image - 139 in totally_green
# Processing Image - 140 in totally_green
# Processing Image - 141 in totally_green
# Processing Image - 142 in totally_green
# Processing Image - 143 in totally_green
# Processing Image - 144 in totally_green
# Processing Image - 145 in totally_green
# Processing Image - 146 in totally_green
# Processing Image - 147 in totally_green
# Processing Image - 148 in totally_green
# Processing Image - 149 in totally_green
# Processing Image - 150 in totally_green
# Processing Image - 151 in totally_green
# Processing Image - 152 in totally_green
# Processing Image - 153 in totally_green
# Processing Image - 154 in totally_green
# Processing Image - 155 in totally_green
# Processing Image - 156 in totally_green
# Processing Image - 157 in totally_green
# Processing Image - 158 in totally_green
# Processing Image - 159 in totally_green
# Processing Image - 160 in totally_green
# Processing Image - 161 in totally_green
# Processing Image - 162 in totally_green
# Processing Image - 163 in totally_green
# Processing Image - 164 in totally_green
# Processing Image - 165 in totally_green
# Processing Image - 166 in totally_green
# Processing Image - 167 in totally_green
# Processing Image - 168 in totally_green
# Processing Image - 169 in totally_green
# Processing Image - 170 in totally_green
# Processing Image - 171 in totally_green
# Processing Image - 172 in totally_green
# Processing Image - 173 in totally_green
# Processing Image - 174 in totally_green
# Processing Image - 175 in totally_green
# Processing Image - 176 in totally_green
# Processing Image - 177 in totally_green
# Processing Image - 178 in totally_green
# Processing Image - 179 in totally_green
# Processing Image - 180 in totally_green
# Processing Image - 181 in totally_green
# Processing Image - 182 in totally_green
# Processing Image - 183 in totally_green
# Processing Image - 184 in totally_green
# Processing Image - 185 in totally_green
# Processing Image - 186 in totally_green
# Processing Image - 187 in totally_green
# Processing Image - 188 in totally_green
# Processing Image - 189 in totally_green
# Processing Image - 190 in totally_green
# Processing Image - 191 in totally_green
# Processing Image - 192 in totally_green
# Processing Image - 193 in totally_green
# Processing Image - 194 in totally_green
# Processing Image - 195 in totally_green
# Processing Image - 196 in totally_green
# Processing Image - 197 in totally_green
# Processing Image - 198 in totally_green
# Processing Image - 199 in totally_green
# Processing Image - 200 in totally_green
# Processing Image - 201 in totally_green
# Processing Image - 202 in totally_green
# Processing Image - 203 in totally_green
# Processing Image - 204 in totally_green
# Processing Image - 205 in totally_green
# Processing Image - 206 in totally_green
# Processing Image - 207 in totally_green
# Processing Image - 208 in totally_green
# Processing Image - 209 in totally_green
# Processing Image - 210 in totally_green
# Processing Image - 211 in totally_green
# Processing Image - 212 in totally_green
# Processing Image - 213 in totally_green
# Processing Image - 214 in totally_green
# Processing Image - 215 in totally_green
# Processing Image - 216 in totally_green
# Processing Image - 217 in totally_green
# Processing Image - 218 in totally_green
# Processing Image - 219 in totally_green
# Processing Image - 220 in totally_green
# Processing Image - 221 in totally_green
# Processing Image - 222 in totally_green
# Processing Image - 223 in totally_green
# Processing Image - 224 in totally_green
# Processing Image - 225 in totally_green
# Processing Image - 226 in totally_green
# Processing Image - 227 in totally_green
# Processing Image - 228 in totally_green
# Processing Image - 229 in totally_green
# Processing Image - 230 in totally_green
# Processing Image - 231 in totally_green
# Processing Image - 232 in totally_green
# Processing Image - 233 in totally_green
# Processing Image - 234 in totally_green
# Processing Image - 235 in totally_green
# Processing Image - 236 in totally_green
# Processing Image - 237 in totally_green
# Processing Image - 238 in totally_green
# Processing Image - 239 in totally_green
# Processing Image - 240 in totally_green
# Processing Image - 241 in totally_green
# Processing Image - 242 in totally_green
# Processing Image - 243 in totally_green
# Processing Image - 244 in totally_green
# Processing Image - 245 in totally_green
# Processing Image - 246 in totally_green
# Processing Image - 247 in totally_green
# Processing Image - 248 in totally_green
# Processing Image - 249 in totally_green
# Processing Image - 250 in totally_green
# Processing Image - 251 in totally_green
# Processing Image - 252 in totally_green
# Processing Image - 253 in totally_green
# Processing Image - 254 in totally_green
# Processing Image - 255 in totally_green
# Processing Image - 256 in totally_green
# Processing Image - 257 in totally_green
# Processing Image - 258 in totally_green
# Processing Image - 259 in totally_green
# Processing Image - 260 in totally_green
# Processing Image - 261 in totally_green
# Processing Image - 262 in totally_green
# Processing Image - 263 in totally_green
# Processing Image - 264 in totally_green
# Processing Image - 265 in totally_green
# Processing Image - 266 in totally_green
# Processing Image - 267 in totally_green
# Processing Image - 268 in totally_green
# Processing Image - 269 in totally_green
# Processing Image - 270 in totally_green
# Processing Image - 271 in totally_green
# Processing Image - 272 in totally_green
# Processing Image - 273 in totally_green
# Processing Image - 274 in totally_green
# Processing Image - 275 in totally_green
# Processing Image - 276 in totally_green
# Processing Image - 277 in totally_green
# Processing Image - 278 in totally_green
# Processing Image - 279 in totally_green
# Processing Image - 280 in totally_green
# Processing Image - 281 in totally_green
# Processing Image - 282 in totally_green
# Processing Image - 283 in totally_green
# Processing Image - 284 in totally_green
# Processing Image - 285 in totally_green
# Processing Image - 286 in totally_green
# Processing Image - 287 in totally_green
# Processing Image - 288 in totally_green
# Processing Image - 289 in totally_green
# Processing Image - 290 in totally_green
# Processing Image - 291 in totally_green
# Processing Image - 292 in totally_green
# Processing Image - 293 in totally_green
# Processing Image - 294 in totally_green
# Processing Image - 295 in totally_green
# Processing Image - 296 in totally_green
# Processing Image - 297 in totally_green
# Processing Image - 298 in totally_green
# Processing Image - 299 in totally_green
# Processing Image - 300 in totally_green
# Processing Image - 301 in totally_green
# Processing Image - 302 in totally_green
# Processing Image - 303 in totally_green
# Processing Image - 304 in totally_green
# Processing Image - 305 in totally_green
# Processing Image - 306 in totally_green
# Processing Image - 307 in totally_green
# Processing Image - 308 in totally_green
# Processing Image - 309 in totally_green
# Processing Image - 310 in totally_green
# Processing Image - 311 in totally_green
# Processing Image - 312 in totally_green
# Processing Image - 313 in totally_green
# Processing Image - 314 in totally_green
# Processing Image - 315 in totally_green
# Processing Image - 316 in totally_green
# Processing Image - 317 in totally_green
# Processing Image - 318 in totally_green
# Processing Image - 319 in totally_green
# Processing Image - 320 in totally_green
# Processing Image - 321 in totally_green
# Processing Image - 322 in totally_green
# Processing Image - 323 in totally_green
# Processing Image - 324 in totally_green
# Processing Image - 325 in totally_green
# Processing Image - 326 in totally_green
# Processing Image - 327 in totally_green
# Processing Image - 328 in totally_green
# Processing Image - 329 in totally_green
# Processing Image - 330 in totally_green
# Processing Image - 331 in totally_green
# Processing Image - 332 in totally_green
# Processing Image - 333 in totally_green
# Processing Image - 334 in totally_green
# Processing Image - 335 in totally_green
# Processing Image - 336 in totally_green
# Processing Image - 337 in totally_green
# Processing Image - 338 in totally_green
# Processing Image - 339 in totally_green
# Processing Image - 340 in totally_green
# Processing Image - 341 in totally_green
# Processing Image - 342 in totally_green
# Processing Image - 343 in totally_green
# Processing Image - 344 in totally_green
# Processing Image - 345 in totally_green
# Processing Image - 346 in totally_green
# Processing Image - 347 in totally_green
# Processing Image - 348 in totally_green
# Processing Image - 349 in totally_green
# Processing Image - 350 in totally_green
# Processing Image - 351 in totally_green
# Processing Image - 352 in totally_green
# Processing Image - 353 in totally_green
# Processing Image - 354 in totally_green
# Processing Image - 355 in totally_green
# Processing Image - 356 in totally_green
# Processing Image - 357 in totally_green
# Processing Image - 358 in totally_green
# Processing Image - 359 in totally_green
# Processing Image - 360 in totally_green
# Processing Image - 361 in totally_green
# Processing Image - 362 in totally_green
# Processing Image - 363 in totally_green
# Processing Image - 364 in totally_green
# Processing Image - 365 in totally_green
# Processing Image - 366 in totally_green
# Processing Image - 367 in totally_green
# Processing Image - 368 in totally_green
# Processing Image - 369 in totally_green
# Processing Image - 370 in totally_green
# Processing Image - 371 in totally_green
# Processing Image - 372 in totally_green
# Processing Image - 373 in totally_green
# Processing Image - 374 in totally_green
# Processing Image - 375 in totally_green
# Processing Image - 376 in totally_green
# Processing Image - 377 in totally_green
# Processing Image - 378 in totally_green
# Processing Image - 379 in totally_green
# Processing Image - 380 in totally_green
# Processing Image - 381 in totally_green
# Processing Image - 382 in totally_green
# Processing Image - 383 in totally_green
# Processing Image - 384 in totally_green
# Processing Image - 385 in totally_green
# Processing Image - 386 in totally_green
# Processing Image - 387 in totally_green
# Processing Image - 388 in totally_green
# Processing Image - 389 in totally_green
# Processing Image - 390 in totally_green
# Processing Image - 391 in totally_green
# Processing Image - 392 in totally_green
# Processing Image - 393 in totally_green
# Processing Image - 394 in totally_green
# Processing Image - 395 in totally_green
# Processing Image - 396 in totally_green
# Processing Image - 397 in totally_green
# Processing Image - 398 in totally_green
# Processing Image - 399 in totally_green
# Processing Image - 400 in totally_green
# Processing Image - 401 in totally_green
# Processing Image - 402 in totally_green
# Processing Image - 403 in totally_green
# Processing Image - 404 in totally_green
# Processing Image - 405 in totally_green
# Processing Image - 406 in totally_green
# Processing Image - 407 in totally_green
# Processing Image - 408 in totally_green
# Processing Image - 409 in totally_green
# Processing Image - 410 in totally_green
# Processing Image - 411 in totally_green
# Processing Image - 412 in totally_green
# Processing Image - 413 in totally_green
# Processing Image - 1 in yellow_with_brown_spots
# Processing Image - 2 in yellow_with_brown_spots
# Processing Image - 3 in yellow_with_brown_spots
# Processing Image - 4 in yellow_with_brown_spots
# Processing Image - 5 in yellow_with_brown_spots
# Processing Image - 6 in yellow_with_brown_spots
# Processing Image - 7 in yellow_with_brown_spots
# Processing Image - 8 in yellow_with_brown_spots
# Processing Image - 9 in yellow_with_brown_spots
# Processing Image - 10 in yellow_with_brown_spots
# Processing Image - 11 in yellow_with_brown_spots
# Processing Image - 12 in yellow_with_brown_spots
# Processing Image - 13 in yellow_with_brown_spots
# Processing Image - 14 in yellow_with_brown_spots
# Processing Image - 15 in yellow_with_brown_spots
# Processing Image - 16 in yellow_with_brown_spots
# Processing Image - 17 in yellow_with_brown_spots
# Processing Image - 18 in yellow_with_brown_spots
# Processing Image - 19 in yellow_with_brown_spots
# Processing Image - 20 in yellow_with_brown_spots
# Processing Image - 21 in yellow_with_brown_spots
# Processing Image - 22 in yellow_with_brown_spots
# Processing Image - 23 in yellow_with_brown_spots
# Processing Image - 24 in yellow_with_brown_spots
# Processing Image - 25 in yellow_with_brown_spots
# Processing Image - 26 in yellow_with_brown_spots
# Processing Image - 27 in yellow_with_brown_spots
# Processing Image - 28 in yellow_with_brown_spots
# Processing Image - 29 in yellow_with_brown_spots
# Processing Image - 30 in yellow_with_brown_spots
# Processing Image - 31 in yellow_with_brown_spots
# Processing Image - 32 in yellow_with_brown_spots
# Processing Image - 33 in yellow_with_brown_spots
# Processing Image - 34 in yellow_with_brown_spots
# Processing Image - 35 in yellow_with_brown_spots
# Processing Image - 36 in yellow_with_brown_spots
# Processing Image - 37 in yellow_with_brown_spots
# Processing Image - 38 in yellow_with_brown_spots
# Processing Image - 39 in yellow_with_brown_spots
# Processing Image - 40 in yellow_with_brown_spots
# Processing Image - 41 in yellow_with_brown_spots
# Processing Image - 42 in yellow_with_brown_spots
# Processing Image - 43 in yellow_with_brown_spots
# Processing Image - 44 in yellow_with_brown_spots
# Processing Image - 45 in yellow_with_brown_spots
# Processing Image - 46 in yellow_with_brown_spots
# Processing Image - 47 in yellow_with_brown_spots
# Processing Image - 48 in yellow_with_brown_spots
# Processing Image - 49 in yellow_with_brown_spots
# Processing Image - 50 in yellow_with_brown_spots
# Processing Image - 51 in yellow_with_brown_spots
# Processing Image - 52 in yellow_with_brown_spots
# Processing Image - 53 in yellow_with_brown_spots
# Processing Image - 54 in yellow_with_brown_spots
# Processing Image - 55 in yellow_with_brown_spots
# Processing Image - 56 in yellow_with_brown_spots
# Processing Image - 57 in yellow_with_brown_spots
# Processing Image - 58 in yellow_with_brown_spots
# Processing Image - 59 in yellow_with_brown_spots
# Processing Image - 60 in yellow_with_brown_spots
# Processing Image - 61 in yellow_with_brown_spots
# Processing Image - 62 in yellow_with_brown_spots
# Processing Image - 63 in yellow_with_brown_spots
# Processing Image - 64 in yellow_with_brown_spots
# Processing Image - 65 in yellow_with_brown_spots
# Processing Image - 66 in yellow_with_brown_spots
# Processing Image - 67 in yellow_with_brown_spots
# Processing Image - 68 in yellow_with_brown_spots
# Processing Image - 69 in yellow_with_brown_spots
# Processing Image - 70 in yellow_with_brown_spots
# Processing Image - 71 in yellow_with_brown_spots
# Processing Image - 72 in yellow_with_brown_spots
# Processing Image - 73 in yellow_with_brown_spots
# Processing Image - 74 in yellow_with_brown_spots
# Processing Image - 75 in yellow_with_brown_spots
# Processing Image - 76 in yellow_with_brown_spots
# Processing Image - 77 in yellow_with_brown_spots
# Processing Image - 78 in yellow_with_brown_spots
# Processing Image - 79 in yellow_with_brown_spots
# Processing Image - 80 in yellow_with_brown_spots
# Processing Image - 81 in yellow_with_brown_spots
# Processing Image - 82 in yellow_with_brown_spots
# Processing Image - 83 in yellow_with_brown_spots
# Processing Image - 84 in yellow_with_brown_spots
# Processing Image - 85 in yellow_with_brown_spots
# Processing Image - 86 in yellow_with_brown_spots
# Processing Image - 87 in yellow_with_brown_spots
# Processing Image - 88 in yellow_with_brown_spots
# Processing Image - 89 in yellow_with_brown_spots
# Processing Image - 90 in yellow_with_brown_spots
# Processing Image - 91 in yellow_with_brown_spots
# Processing Image - 92 in yellow_with_brown_spots
# Processing Image - 93 in yellow_with_brown_spots
# Processing Image - 94 in yellow_with_brown_spots
# Processing Image - 95 in yellow_with_brown_spots
# Processing Image - 96 in yellow_with_brown_spots
# Processing Image - 97 in yellow_with_brown_spots
# Processing Image - 98 in yellow_with_brown_spots
# Processing Image - 99 in yellow_with_brown_spots
# Processing Image - 100 in yellow_with_brown_spots
# Processing Image - 101 in yellow_with_brown_spots
# Processing Image - 102 in yellow_with_brown_spots
# Processing Image - 103 in yellow_with_brown_spots
# Processing Image - 104 in yellow_with_brown_spots
# Processing Image - 105 in yellow_with_brown_spots
# Processing Image - 106 in yellow_with_brown_spots
# Processing Image - 107 in yellow_with_brown_spots
# Processing Image - 108 in yellow_with_brown_spots
# Processing Image - 109 in yellow_with_brown_spots
# Processing Image - 110 in yellow_with_brown_spots
# Processing Image - 111 in yellow_with_brown_spots
# Processing Image - 112 in yellow_with_brown_spots
# Processing Image - 113 in yellow_with_brown_spots
# Processing Image - 114 in yellow_with_brown_spots
# Processing Image - 115 in yellow_with_brown_spots
# Processing Image - 116 in yellow_with_brown_spots
# Processing Image - 117 in yellow_with_brown_spots
# Processing Image - 118 in yellow_with_brown_spots
# Processing Image - 119 in yellow_with_brown_spots
# Processing Image - 120 in yellow_with_brown_spots
# Processing Image - 121 in yellow_with_brown_spots
# Processing Image - 122 in yellow_with_brown_spots
# Processing Image - 123 in yellow_with_brown_spots
# Processing Image - 124 in yellow_with_brown_spots
# Processing Image - 125 in yellow_with_brown_spots
# Processing Image - 126 in yellow_with_brown_spots
# Processing Image - 127 in yellow_with_brown_spots
# Processing Image - 128 in yellow_with_brown_spots
# Processing Image - 129 in yellow_with_brown_spots
# Processing Image - 130 in yellow_with_brown_spots
# Processing Image - 131 in yellow_with_brown_spots
# Processing Image - 132 in yellow_with_brown_spots
# Processing Image - 133 in yellow_with_brown_spots
# Processing Image - 134 in yellow_with_brown_spots
# Processing Image - 135 in yellow_with_brown_spots
# Processing Image - 136 in yellow_with_brown_spots
# Processing Image - 137 in yellow_with_brown_spots
# Processing Image - 138 in yellow_with_brown_spots
# Processing Image - 139 in yellow_with_brown_spots
# Processing Image - 140 in yellow_with_brown_spots
# Processing Image - 141 in yellow_with_brown_spots
# Processing Image - 142 in yellow_with_brown_spots
# Processing Image - 143 in yellow_with_brown_spots
# Processing Image - 144 in yellow_with_brown_spots
# Processing Image - 145 in yellow_with_brown_spots
# Processing Image - 146 in yellow_with_brown_spots
# Processing Image - 147 in yellow_with_brown_spots
# Processing Image - 148 in yellow_with_brown_spots
# Processing Image - 149 in yellow_with_brown_spots
# Processing Image - 150 in yellow_with_brown_spots
# Processing Image - 151 in yellow_with_brown_spots
# Processing Image - 152 in yellow_with_brown_spots
# Processing Image - 153 in yellow_with_brown_spots
# Processing Image - 154 in yellow_with_brown_spots
# Processing Image - 155 in yellow_with_brown_spots
# Processing Image - 156 in yellow_with_brown_spots
# Processing Image - 157 in yellow_with_brown_spots
# Processing Image - 158 in yellow_with_brown_spots
# Processing Image - 159 in yellow_with_brown_spots
# Processing Image - 160 in yellow_with_brown_spots
# Processing Image - 161 in yellow_with_brown_spots
# Processing Image - 162 in yellow_with_brown_spots
# Processing Image - 163 in yellow_with_brown_spots
# Processing Image - 164 in yellow_with_brown_spots
# Processing Image - 165 in yellow_with_brown_spots
# Processing Image - 166 in yellow_with_brown_spots
# Processing Image - 167 in yellow_with_brown_spots
# Processing Image - 168 in yellow_with_brown_spots
# Processing Image - 169 in yellow_with_brown_spots
# Processing Image - 170 in yellow_with_brown_spots
# Processing Image - 171 in yellow_with_brown_spots
# Processing Image - 172 in yellow_with_brown_spots
# Processing Image - 173 in yellow_with_brown_spots
# Processing Image - 174 in yellow_with_brown_spots
# Processing Image - 175 in yellow_with_brown_spots
# Processing Image - 176 in yellow_with_brown_spots
# Processing Image - 177 in yellow_with_brown_spots
# Processing Image - 178 in yellow_with_brown_spots
# Processing Image - 179 in yellow_with_brown_spots
# Processing Image - 180 in yellow_with_brown_spots
# Processing Image - 181 in yellow_with_brown_spots
# Processing Image - 182 in yellow_with_brown_spots
# Processing Image - 183 in yellow_with_brown_spots
# Processing Image - 184 in yellow_with_brown_spots
# Processing Image - 185 in yellow_with_brown_spots
# Processing Image - 186 in yellow_with_brown_spots
# Processing Image - 187 in yellow_with_brown_spots
# Processing Image - 188 in yellow_with_brown_spots
# Processing Image - 189 in yellow_with_brown_spots
# Processing Image - 190 in yellow_with_brown_spots
# Processing Image - 191 in yellow_with_brown_spots
# Processing Image - 192 in yellow_with_brown_spots
# Processing Image - 193 in yellow_with_brown_spots
# Processing Image - 194 in yellow_with_brown_spots
# Processing Image - 195 in yellow_with_brown_spots
# Processing Image - 196 in yellow_with_brown_spots
# Processing Image - 197 in yellow_with_brown_spots
# Processing Image - 198 in yellow_with_brown_spots
# Processing Image - 199 in yellow_with_brown_spots
# Processing Image - 200 in yellow_with_brown_spots
# Processing Image - 201 in yellow_with_brown_spots
# Processing Image - 202 in yellow_with_brown_spots
# Processing Image - 203 in yellow_with_brown_spots
# Processing Image - 204 in yellow_with_brown_spots
# Processing Image - 205 in yellow_with_brown_spots
# Processing Image - 206 in yellow_with_brown_spots
# Processing Image - 207 in yellow_with_brown_spots
# Processing Image - 208 in yellow_with_brown_spots
# Processing Image - 209 in yellow_with_brown_spots
# Processing Image - 210 in yellow_with_brown_spots
# Processing Image - 211 in yellow_with_brown_spots
# Processing Image - 212 in yellow_with_brown_spots
# Processing Image - 213 in yellow_with_brown_spots
# Processing Image - 214 in yellow_with_brown_spots
# Processing Image - 215 in yellow_with_brown_spots
# Processing Image - 216 in yellow_with_brown_spots
# Processing Image - 217 in yellow_with_brown_spots
# Processing Image - 218 in yellow_with_brown_spots
# Processing Image - 219 in yellow_with_brown_spots
# Processing Image - 220 in yellow_with_brown_spots
# Processing Image - 221 in yellow_with_brown_spots
# Processing Image - 222 in yellow_with_brown_spots
# Processing Image - 223 in yellow_with_brown_spots
# Processing Image - 224 in yellow_with_brown_spots
# Processing Image - 225 in yellow_with_brown_spots
# Processing Image - 226 in yellow_with_brown_spots
# Processing Image - 227 in yellow_with_brown_spots
# Processing Image - 228 in yellow_with_brown_spots
# Processing Image - 229 in yellow_with_brown_spots
# Processing Image - 230 in yellow_with_brown_spots
# Processing Image - 231 in yellow_with_brown_spots
# Processing Image - 232 in yellow_with_brown_spots
# Processing Image - 233 in yellow_with_brown_spots
# Processing Image - 234 in yellow_with_brown_spots
# Processing Image - 235 in yellow_with_brown_spots
# Processing Image - 236 in yellow_with_brown_spots
# Processing Image - 237 in yellow_with_brown_spots
# Processing Image - 238 in yellow_with_brown_spots
# Processing Image - 239 in yellow_with_brown_spots
# Processing Image - 240 in yellow_with_brown_spots
# Processing Image - 241 in yellow_with_brown_spots
# Processing Image - 242 in yellow_with_brown_spots
# Processing Image - 243 in yellow_with_brown_spots
# Processing Image - 244 in yellow_with_brown_spots
# Processing Image - 245 in yellow_with_brown_spots
# Processing Image - 246 in yellow_with_brown_spots
# Processing Image - 247 in yellow_with_brown_spots
# Processing Image - 248 in yellow_with_brown_spots
# Processing Image - 249 in yellow_with_brown_spots
# Processing Image - 250 in yellow_with_brown_spots
# Processing Image - 251 in yellow_with_brown_spots
# Processing Image - 252 in yellow_with_brown_spots
# Processing Image - 253 in yellow_with_brown_spots
# Processing Image - 254 in yellow_with_brown_spots
# Processing Image - 255 in yellow_with_brown_spots
# Processing Image - 256 in yellow_with_brown_spots
# Processing Image - 257 in yellow_with_brown_spots
# Processing Image - 258 in yellow_with_brown_spots
# Processing Image - 259 in yellow_with_brown_spots
# Processing Image - 260 in yellow_with_brown_spots
# Processing Image - 261 in yellow_with_brown_spots
# Processing Image - 262 in yellow_with_brown_spots
# Processing Image - 263 in yellow_with_brown_spots
# Processing Image - 264 in yellow_with_brown_spots
# Processing Image - 265 in yellow_with_brown_spots
# Processing Image - 266 in yellow_with_brown_spots
# Processing Image - 267 in yellow_with_brown_spots
# Processing Image - 268 in yellow_with_brown_spots
# Processing Image - 269 in yellow_with_brown_spots
# Processing Image - 270 in yellow_with_brown_spots
# Processing Image - 271 in yellow_with_brown_spots
# Processing Image - 272 in yellow_with_brown_spots
# Processing Image - 273 in yellow_with_brown_spots
# Processing Image - 274 in yellow_with_brown_spots
# Processing Image - 275 in yellow_with_brown_spots
# Processing Image - 276 in yellow_with_brown_spots
# Processing Image - 277 in yellow_with_brown_spots
# Processing Image - 278 in yellow_with_brown_spots
# Processing Image - 279 in yellow_with_brown_spots
# Processing Image - 280 in yellow_with_brown_spots
# Processing Image - 281 in yellow_with_brown_spots
# Processing Image - 282 in yellow_with_brown_spots
# Processing Image - 283 in yellow_with_brown_spots
# Processing Image - 284 in yellow_with_brown_spots
# Processing Image - 285 in yellow_with_brown_spots
# Processing Image - 286 in yellow_with_brown_spots
# Processing Image - 287 in yellow_with_brown_spots
# Processing Image - 288 in yellow_with_brown_spots
# Processing Image - 289 in yellow_with_brown_spots
# Processing Image - 290 in yellow_with_brown_spots
# Processing Image - 291 in yellow_with_brown_spots
# Processing Image - 292 in yellow_with_brown_spots
# Processing Image - 293 in yellow_with_brown_spots
# Processing Image - 294 in yellow_with_brown_spots
# Processing Image - 295 in yellow_with_brown_spots
# Processing Image - 296 in yellow_with_brown_spots
# Processing Image - 297 in yellow_with_brown_spots
# Processing Image - 298 in yellow_with_brown_spots
# Processing Image - 299 in yellow_with_brown_spots
# Processing Image - 300 in yellow_with_brown_spots
# Processing Image - 301 in yellow_with_brown_spots
# Processing Image - 302 in yellow_with_brown_spots
# Processing Image - 303 in yellow_with_brown_spots
# Processing Image - 304 in yellow_with_brown_spots
# Processing Image - 305 in yellow_with_brown_spots
# Processing Image - 306 in yellow_with_brown_spots
# Processing Image - 307 in yellow_with_brown_spots
# Processing Image - 308 in yellow_with_brown_spots
# Processing Image - 309 in yellow_with_brown_spots
# Processing Image - 310 in yellow_with_brown_spots
# Processing Image - 311 in yellow_with_brown_spots
# Processing Image - 312 in yellow_with_brown_spots
# Processing Image - 313 in yellow_with_brown_spots
# Processing Image - 314 in yellow_with_brown_spots
# Processing Image - 315 in yellow_with_brown_spots
# Processing Image - 316 in yellow_with_brown_spots
# Processing Image - 317 in yellow_with_brown_spots
# Processing Image - 318 in yellow_with_brown_spots
# Processing Image - 319 in yellow_with_brown_spots
# Processing Image - 320 in yellow_with_brown_spots
# Processing Image - 321 in yellow_with_brown_spots
# Processing Image - 322 in yellow_with_brown_spots
# Processing Image - 323 in yellow_with_brown_spots
# Processing Image - 324 in yellow_with_brown_spots
# Processing Image - 325 in yellow_with_brown_spots
# Processing Image - 326 in yellow_with_brown_spots
# Processing Image - 327 in yellow_with_brown_spots
# Processing Image - 328 in yellow_with_brown_spots
# Processing Image - 329 in yellow_with_brown_spots
# Processing Image - 330 in yellow_with_brown_spots
# Processing Image - 331 in yellow_with_brown_spots
# Processing Image - 332 in yellow_with_brown_spots
# Processing Image - 333 in yellow_with_brown_spots
# Processing Image - 334 in yellow_with_brown_spots
# Processing Image - 335 in yellow_with_brown_spots
# Processing Image - 336 in yellow_with_brown_spots
# Processing Image - 337 in yellow_with_brown_spots
# Processing Image - 338 in yellow_with_brown_spots
# Processing Image - 339 in yellow_with_brown_spots
# Processing Image - 340 in yellow_with_brown_spots
# Processing Image - 341 in yellow_with_brown_spots
# Processing Image - 342 in yellow_with_brown_spots
# Processing Image - 343 in yellow_with_brown_spots
# Processing Image - 344 in yellow_with_brown_spots
# Processing Image - 345 in yellow_with_brown_spots
# Processing Image - 346 in yellow_with_brown_spots
# Processing Image - 347 in yellow_with_brown_spots
# Processing Image - 348 in yellow_with_brown_spots
# Processing Image - 349 in yellow_with_brown_spots
# Processing Image - 350 in yellow_with_brown_spots
# Processing Image - 351 in yellow_with_brown_spots
# Processing Image - 352 in yellow_with_brown_spots
# Processing Image - 353 in yellow_with_brown_spots
# Processing Image - 354 in yellow_with_brown_spots
# Processing Image - 355 in yellow_with_brown_spots
# Processing Image - 356 in yellow_with_brown_spots
# Processing Image - 357 in yellow_with_brown_spots
# Processing Image - 358 in yellow_with_brown_spots
# Processing Image - 359 in yellow_with_brown_spots
# Processing Image - 360 in yellow_with_brown_spots
# Processing Image - 361 in yellow_with_brown_spots
# Processing Image - 362 in yellow_with_brown_spots
# Processing Image - 363 in yellow_with_brown_spots
# Processing Image - 364 in yellow_with_brown_spots
# Processing Image - 365 in yellow_with_brown_spots
# Processing Image - 366 in yellow_with_brown_spots
# Processing Image - 367 in yellow_with_brown_spots
# Processing Image - 368 in yellow_with_brown_spots
# Processing Image - 369 in yellow_with_brown_spots
# Processing Image - 370 in yellow_with_brown_spots
# Processing Image - 371 in yellow_with_brown_spots
# Processing Image - 372 in yellow_with_brown_spots
# Processing Image - 373 in yellow_with_brown_spots
# Processing Image - 374 in yellow_with_brown_spots
# Processing Image - 375 in yellow_with_brown_spots
# Processing Image - 376 in yellow_with_brown_spots
# Processing Image - 377 in yellow_with_brown_spots
# Processing Image - 378 in yellow_with_brown_spots
# Processing Image - 379 in yellow_with_brown_spots
# Processing Image - 380 in yellow_with_brown_spots
# Processing Image - 381 in yellow_with_brown_spots
# Processing Image - 382 in yellow_with_brown_spots
# Processing Image - 383 in yellow_with_brown_spots
# Processing Image - 384 in yellow_with_brown_spots
# Processing Image - 385 in yellow_with_brown_spots
# Processing Image - 386 in yellow_with_brown_spots
# Processing Image - 387 in yellow_with_brown_spots
# Processing Image - 388 in yellow_with_brown_spots
# Processing Image - 389 in yellow_with_brown_spots
# Processing Image - 390 in yellow_with_brown_spots
# Processing Image - 391 in yellow_with_brown_spots
# Processing Image - 392 in yellow_with_brown_spots
# Processing Image - 393 in yellow_with_brown_spots
# Processing Image - 394 in yellow_with_brown_spots
# Processing Image - 395 in yellow_with_brown_spots
# Processing Image - 396 in yellow_with_brown_spots
# Processing Image - 397 in yellow_with_brown_spots
# Processing Image - 398 in yellow_with_brown_spots
# Processing Image - 399 in yellow_with_brown_spots
# Processing Image - 400 in yellow_with_brown_spots
# Processing Image - 401 in yellow_with_brown_spots
# Processing Image - 402 in yellow_with_brown_spots
# Processing Image - 403 in yellow_with_brown_spots
# Processing Image - 404 in yellow_with_brown_spots
# Processing Image - 405 in yellow_with_brown_spots
# Processing Image - 406 in yellow_with_brown_spots
# Processing Image - 407 in yellow_with_brown_spots
# Processing Image - 408 in yellow_with_brown_spots
# Processing Image - 409 in yellow_with_brown_spots
# Processing Image - 410 in yellow_with_brown_spots
# Processing Image - 411 in yellow_with_brown_spots
# Processing Image - 412 in yellow_with_brown_spots
# Processing Image - 413 in yellow_with_brown_spots
# Processing Image - 414 in yellow_with_brown_spots
# Processing Image - 415 in yellow_with_brown_spots
# Processing Image - 416 in yellow_with_brown_spots
# Processing Image - 417 in yellow_with_brown_spots
# Processing Image - 418 in yellow_with_brown_spots
# Processing Image - 419 in yellow_with_brown_spots
# Processing Image - 420 in yellow_with_brown_spots
# Processing Image - 421 in yellow_with_brown_spots
# Processing Image - 422 in yellow_with_brown_spots
# Processing Image - 423 in yellow_with_brown_spots
# Processing Image - 1 in yellow_with_green_tips
# Processing Image - 2 in yellow_with_green_tips
# Processing Image - 3 in yellow_with_green_tips
# Processing Image - 4 in yellow_with_green_tips
# Processing Image - 5 in yellow_with_green_tips
# Processing Image - 6 in yellow_with_green_tips
# Processing Image - 7 in yellow_with_green_tips
# Processing Image - 8 in yellow_with_green_tips
# Processing Image - 9 in yellow_with_green_tips
# Processing Image - 10 in yellow_with_green_tips
# Processing Image - 11 in yellow_with_green_tips
# Processing Image - 12 in yellow_with_green_tips
# Processing Image - 13 in yellow_with_green_tips
# Processing Image - 14 in yellow_with_green_tips
# Processing Image - 15 in yellow_with_green_tips
# Processing Image - 16 in yellow_with_green_tips
# Processing Image - 17 in yellow_with_green_tips
# Processing Image - 18 in yellow_with_green_tips
# Processing Image - 19 in yellow_with_green_tips
# Processing Image - 20 in yellow_with_green_tips
# Processing Image - 21 in yellow_with_green_tips
# Processing Image - 22 in yellow_with_green_tips
# Processing Image - 23 in yellow_with_green_tips
# Processing Image - 24 in yellow_with_green_tips
# Processing Image - 25 in yellow_with_green_tips
# Processing Image - 26 in yellow_with_green_tips
# Processing Image - 27 in yellow_with_green_tips
# Processing Image - 28 in yellow_with_green_tips
# Processing Image - 29 in yellow_with_green_tips
# Processing Image - 30 in yellow_with_green_tips
# Processing Image - 31 in yellow_with_green_tips
# Processing Image - 32 in yellow_with_green_tips
# Processing Image - 33 in yellow_with_green_tips
# Processing Image - 34 in yellow_with_green_tips
# Processing Image - 35 in yellow_with_green_tips
# Processing Image - 36 in yellow_with_green_tips
# Processing Image - 37 in yellow_with_green_tips
# Processing Image - 38 in yellow_with_green_tips
# Processing Image - 39 in yellow_with_green_tips
# Processing Image - 40 in yellow_with_green_tips
# Processing Image - 41 in yellow_with_green_tips
# Processing Image - 42 in yellow_with_green_tips
# Processing Image - 43 in yellow_with_green_tips
# Processing Image - 44 in yellow_with_green_tips
# Processing Image - 45 in yellow_with_green_tips
# Processing Image - 46 in yellow_with_green_tips
# Processing Image - 47 in yellow_with_green_tips
# Processing Image - 48 in yellow_with_green_tips
# Processing Image - 49 in yellow_with_green_tips
# Processing Image - 50 in yellow_with_green_tips
# Processing Image - 51 in yellow_with_green_tips
# Processing Image - 52 in yellow_with_green_tips
# Processing Image - 53 in yellow_with_green_tips
# Processing Image - 54 in yellow_with_green_tips
# Processing Image - 55 in yellow_with_green_tips
# Processing Image - 56 in yellow_with_green_tips
# Processing Image - 57 in yellow_with_green_tips
# Processing Image - 58 in yellow_with_green_tips
# Processing Image - 59 in yellow_with_green_tips
# Processing Image - 60 in yellow_with_green_tips
# Processing Image - 61 in yellow_with_green_tips
# Processing Image - 62 in yellow_with_green_tips
# Processing Image - 63 in yellow_with_green_tips
# Processing Image - 64 in yellow_with_green_tips
# Processing Image - 65 in yellow_with_green_tips
# Processing Image - 66 in yellow_with_green_tips
# Processing Image - 67 in yellow_with_green_tips
# Processing Image - 68 in yellow_with_green_tips
# Processing Image - 69 in yellow_with_green_tips
# Processing Image - 70 in yellow_with_green_tips
# Processing Image - 71 in yellow_with_green_tips
# Processing Image - 72 in yellow_with_green_tips
# Processing Image - 73 in yellow_with_green_tips
# Processing Image - 74 in yellow_with_green_tips
# Processing Image - 75 in yellow_with_green_tips
# Processing Image - 76 in yellow_with_green_tips
# Processing Image - 77 in yellow_with_green_tips
# Processing Image - 78 in yellow_with_green_tips
# Processing Image - 79 in yellow_with_green_tips
# Processing Image - 80 in yellow_with_green_tips
# Processing Image - 81 in yellow_with_green_tips
# Processing Image - 82 in yellow_with_green_tips
# Processing Image - 83 in yellow_with_green_tips
# Processing Image - 84 in yellow_with_green_tips
# Processing Image - 85 in yellow_with_green_tips
# Processing Image - 86 in yellow_with_green_tips
# Processing Image - 87 in yellow_with_green_tips
# Processing Image - 88 in yellow_with_green_tips
# Processing Image - 89 in yellow_with_green_tips
# Processing Image - 90 in yellow_with_green_tips
# Processing Image - 91 in yellow_with_green_tips
# Processing Image - 92 in yellow_with_green_tips
# Processing Image - 93 in yellow_with_green_tips
# Processing Image - 94 in yellow_with_green_tips
# Processing Image - 95 in yellow_with_green_tips
# Processing Image - 96 in yellow_with_green_tips
# Processing Image - 97 in yellow_with_green_tips
# Processing Image - 98 in yellow_with_green_tips
# Processing Image - 99 in yellow_with_green_tips
# Processing Image - 100 in yellow_with_green_tips
# Processing Image - 101 in yellow_with_green_tips
# Processing Image - 102 in yellow_with_green_tips
# Processing Image - 103 in yellow_with_green_tips
# Processing Image - 104 in yellow_with_green_tips
# Processing Image - 105 in yellow_with_green_tips
# Processing Image - 106 in yellow_with_green_tips
# Processing Image - 107 in yellow_with_green_tips
# Processing Image - 108 in yellow_with_green_tips
# Processing Image - 109 in yellow_with_green_tips
# Processing Image - 110 in yellow_with_green_tips
# Processing Image - 111 in yellow_with_green_tips
# Processing Image - 112 in yellow_with_green_tips
# Processing Image - 113 in yellow_with_green_tips
# Processing Image - 114 in yellow_with_green_tips
# Processing Image - 115 in yellow_with_green_tips
# Processing Image - 116 in yellow_with_green_tips
# Processing Image - 117 in yellow_with_green_tips
# Processing Image - 118 in yellow_with_green_tips
# Processing Image - 119 in yellow_with_green_tips
# Processing Image - 120 in yellow_with_green_tips
# Processing Image - 121 in yellow_with_green_tips
# Processing Image - 122 in yellow_with_green_tips
# Processing Image - 123 in yellow_with_green_tips
# Processing Image - 124 in yellow_with_green_tips
# Processing Image - 125 in yellow_with_green_tips
# Processing Image - 126 in yellow_with_green_tips
# Processing Image - 127 in yellow_with_green_tips
# Processing Image - 128 in yellow_with_green_tips
# Processing Image - 129 in yellow_with_green_tips
# Processing Image - 130 in yellow_with_green_tips
# Processing Image - 131 in yellow_with_green_tips
# Processing Image - 132 in yellow_with_green_tips
# Processing Image - 133 in yellow_with_green_tips
# Processing Image - 134 in yellow_with_green_tips
# Processing Image - 135 in yellow_with_green_tips
# Processing Image - 136 in yellow_with_green_tips
# Processing Image - 137 in yellow_with_green_tips
# Processing Image - 138 in yellow_with_green_tips
# Processing Image - 139 in yellow_with_green_tips
# Processing Image - 140 in yellow_with_green_tips
# Processing Image - 141 in yellow_with_green_tips
# Processing Image - 142 in yellow_with_green_tips
# Processing Image - 143 in yellow_with_green_tips
# Processing Image - 144 in yellow_with_green_tips
# Processing Image - 145 in yellow_with_green_tips
# Processing Image - 146 in yellow_with_green_tips
# Processing Image - 147 in yellow_with_green_tips
# Processing Image - 148 in yellow_with_green_tips
# Processing Image - 149 in yellow_with_green_tips
# Processing Image - 150 in yellow_with_green_tips
# Processing Image - 151 in yellow_with_green_tips
# Processing Image - 152 in yellow_with_green_tips
# Processing Image - 153 in yellow_with_green_tips
# Processing Image - 154 in yellow_with_green_tips
# Processing Image - 155 in yellow_with_green_tips
# Processing Image - 156 in yellow_with_green_tips
# Processing Image - 157 in yellow_with_green_tips
# Processing Image - 158 in yellow_with_green_tips
# Processing Image - 159 in yellow_with_green_tips
# Processing Image - 160 in yellow_with_green_tips
# Processing Image - 161 in yellow_with_green_tips
# Processing Image - 162 in yellow_with_green_tips
# Processing Image - 163 in yellow_with_green_tips
# Processing Image - 164 in yellow_with_green_tips
# Processing Image - 165 in yellow_with_green_tips
# Processing Image - 166 in yellow_with_green_tips
# Processing Image - 167 in yellow_with_green_tips
# Processing Image - 168 in yellow_with_green_tips
# Processing Image - 169 in yellow_with_green_tips
# Processing Image - 170 in yellow_with_green_tips
# Processing Image - 171 in yellow_with_green_tips
# Processing Image - 172 in yellow_with_green_tips
# Processing Image - 173 in yellow_with_green_tips
# Processing Image - 174 in yellow_with_green_tips
# Processing Image - 175 in yellow_with_green_tips
# Processing Image - 176 in yellow_with_green_tips
# Processing Image - 177 in yellow_with_green_tips
# Processing Image - 178 in yellow_with_green_tips
# Processing Image - 179 in yellow_with_green_tips
# Processing Image - 180 in yellow_with_green_tips
# Processing Image - 181 in yellow_with_green_tips
# Processing Image - 182 in yellow_with_green_tips
# Processing Image - 183 in yellow_with_green_tips
# Processing Image - 184 in yellow_with_green_tips
# Processing Image - 185 in yellow_with_green_tips
# Processing Image - 186 in yellow_with_green_tips
# Processing Image - 187 in yellow_with_green_tips
# Processing Image - 188 in yellow_with_green_tips
# Processing Image - 189 in yellow_with_green_tips
# Processing Image - 190 in yellow_with_green_tips
# Processing Image - 191 in yellow_with_green_tips
# Processing Image - 192 in yellow_with_green_tips
# Processing Image - 193 in yellow_with_green_tips
# Processing Image - 194 in yellow_with_green_tips
# Processing Image - 195 in yellow_with_green_tips
# Processing Image - 196 in yellow_with_green_tips
# Processing Image - 197 in yellow_with_green_tips
# Processing Image - 198 in yellow_with_green_tips
# Processing Image - 199 in yellow_with_green_tips
# Processing Image - 200 in yellow_with_green_tips
# Processing Image - 201 in yellow_with_green_tips
# Processing Image - 202 in yellow_with_green_tips
# Processing Image - 203 in yellow_with_green_tips
# Processing Image - 204 in yellow_with_green_tips
# Processing Image - 205 in yellow_with_green_tips
# Processing Image - 206 in yellow_with_green_tips
# Processing Image - 207 in yellow_with_green_tips
# Processing Image - 208 in yellow_with_green_tips
# Processing Image - 209 in yellow_with_green_tips
# Processing Image - 210 in yellow_with_green_tips
# Processing Image - 211 in yellow_with_green_tips
# Processing Image - 212 in yellow_with_green_tips
# Processing Image - 213 in yellow_with_green_tips
# Processing Image - 214 in yellow_with_green_tips
# Processing Image - 215 in yellow_with_green_tips
# Processing Image - 216 in yellow_with_green_tips
# Processing Image - 217 in yellow_with_green_tips
# Processing Image - 218 in yellow_with_green_tips
# Processing Image - 219 in yellow_with_green_tips
# Processing Image - 220 in yellow_with_green_tips
# Processing Image - 221 in yellow_with_green_tips
# Processing Image - 222 in yellow_with_green_tips
# Processing Image - 223 in yellow_with_green_tips
# Processing Image - 224 in yellow_with_green_tips
# Processing Image - 225 in yellow_with_green_tips
# Processing Image - 226 in yellow_with_green_tips
# Processing Image - 227 in yellow_with_green_tips
# Processing Image - 228 in yellow_with_green_tips
# Processing Image - 229 in yellow_with_green_tips
# Processing Image - 230 in yellow_with_green_tips
# Processing Image - 231 in yellow_with_green_tips
# Processing Image - 232 in yellow_with_green_tips
# Processing Image - 233 in yellow_with_green_tips
# Processing Image - 234 in yellow_with_green_tips
# Processing Image - 235 in yellow_with_green_tips
# Processing Image - 236 in yellow_with_green_tips
# Processing Image - 237 in yellow_with_green_tips
# Processing Image - 238 in yellow_with_green_tips
# Processing Image - 239 in yellow_with_green_tips
# Processing Image - 240 in yellow_with_green_tips
# Processing Image - 241 in yellow_with_green_tips
# Processing Image - 242 in yellow_with_green_tips
# Processing Image - 243 in yellow_with_green_tips
# Processing Image - 244 in yellow_with_green_tips
# Processing Image - 245 in yellow_with_green_tips
# Processing Image - 246 in yellow_with_green_tips
# Processing Image - 247 in yellow_with_green_tips
# Processing Image - 248 in yellow_with_green_tips
# Processing Image - 249 in yellow_with_green_tips
# Processing Image - 250 in yellow_with_green_tips
# Processing Image - 251 in yellow_with_green_tips
# Processing Image - 252 in yellow_with_green_tips
# Processing Image - 253 in yellow_with_green_tips
# Processing Image - 254 in yellow_with_green_tips
# Processing Image - 255 in yellow_with_green_tips
# Processing Image - 256 in yellow_with_green_tips
# Processing Image - 257 in yellow_with_green_tips
# Processing Image - 258 in yellow_with_green_tips
# Processing Image - 259 in yellow_with_green_tips
# Processing Image - 260 in yellow_with_green_tips
# Processing Image - 261 in yellow_with_green_tips
# Processing Image - 262 in yellow_with_green_tips
# Processing Image - 263 in yellow_with_green_tips
# Processing Image - 264 in yellow_with_green_tips
# Processing Image - 265 in yellow_with_green_tips
# Processing Image - 266 in yellow_with_green_tips
# Processing Image - 267 in yellow_with_green_tips
# Processing Image - 268 in yellow_with_green_tips
# Processing Image - 269 in yellow_with_green_tips
# Processing Image - 270 in yellow_with_green_tips
# Processing Image - 271 in yellow_with_green_tips
# Processing Image - 272 in yellow_with_green_tips
# Processing Image - 273 in yellow_with_green_tips
# Processing Image - 274 in yellow_with_green_tips
# Processing Image - 275 in yellow_with_green_tips
# Processing Image - 276 in yellow_with_green_tips
# Processing Image - 277 in yellow_with_green_tips
# Processing Image - 278 in yellow_with_green_tips
# Processing Image - 279 in yellow_with_green_tips
# Processing Image - 280 in yellow_with_green_tips
# Processing Image - 281 in yellow_with_green_tips
# Processing Image - 282 in yellow_with_green_tips
# Processing Image - 283 in yellow_with_green_tips
# Processing Image - 284 in yellow_with_green_tips
# Processing Image - 285 in yellow_with_green_tips
# Processing Image - 286 in yellow_with_green_tips
# Processing Image - 287 in yellow_with_green_tips
# Processing Image - 288 in yellow_with_green_tips
# Processing Image - 289 in yellow_with_green_tips
# Processing Image - 290 in yellow_with_green_tips
# Processing Image - 291 in yellow_with_green_tips
# Processing Image - 292 in yellow_with_green_tips
# Processing Image - 293 in yellow_with_green_tips
# Processing Image - 294 in yellow_with_green_tips
# Processing Image - 295 in yellow_with_green_tips
# Processing Image - 296 in yellow_with_green_tips
# Processing Image - 297 in yellow_with_green_tips
# Processing Image - 298 in yellow_with_green_tips
# Processing Image - 299 in yellow_with_green_tips
# Processing Image - 300 in yellow_with_green_tips
# Processing Image - 301 in yellow_with_green_tips
# Processing Image - 302 in yellow_with_green_tips
# Processing Image - 303 in yellow_with_green_tips
# Processing Image - 304 in yellow_with_green_tips
# Processing Image - 305 in yellow_with_green_tips
# Processing Image - 306 in yellow_with_green_tips
# Processing Image - 307 in yellow_with_green_tips
# Processing Image - 308 in yellow_with_green_tips
# Processing Image - 309 in yellow_with_green_tips
# Processing Image - 310 in yellow_with_green_tips
# Processing Image - 311 in yellow_with_green_tips
# Processing Image - 312 in yellow_with_green_tips
# Processing Image - 313 in yellow_with_green_tips
# Processing Image - 314 in yellow_with_green_tips
# Processing Image - 315 in yellow_with_green_tips
# Processing Image - 316 in yellow_with_green_tips
# Processing Image - 317 in yellow_with_green_tips
# Processing Image - 318 in yellow_with_green_tips
# Processing Image - 319 in yellow_with_green_tips
# Processing Image - 320 in yellow_with_green_tips
# Processing Image - 321 in yellow_with_green_tips
# Processing Image - 322 in yellow_with_green_tips
# Processing Image - 323 in yellow_with_green_tips
# Processing Image - 324 in yellow_with_green_tips
# Processing Image - 325 in yellow_with_green_tips
# Processing Image - 326 in yellow_with_green_tips
# Processing Image - 327 in yellow_with_green_tips
# Processing Image - 328 in yellow_with_green_tips
# Processing Image - 329 in yellow_with_green_tips
# Processing Image - 330 in yellow_with_green_tips
# Processing Image - 331 in yellow_with_green_tips
# Processing Image - 332 in yellow_with_green_tips
# Processing Image - 333 in yellow_with_green_tips
# Processing Image - 334 in yellow_with_green_tips
# Processing Image - 335 in yellow_with_green_tips
# Processing Image - 336 in yellow_with_green_tips
# Processing Image - 337 in yellow_with_green_tips
# Processing Image - 338 in yellow_with_green_tips
# Processing Image - 339 in yellow_with_green_tips
# Processing Image - 340 in yellow_with_green_tips
# Processing Image - 341 in yellow_with_green_tips
# Processing Image - 342 in yellow_with_green_tips
# Processing Image - 343 in yellow_with_green_tips
# Processing Image - 344 in yellow_with_green_tips
# Processing Image - 345 in yellow_with_green_tips
# Processing Image - 346 in yellow_with_green_tips
# Processing Image - 347 in yellow_with_green_tips
# Processing Image - 348 in yellow_with_green_tips
# Processing Image - 349 in yellow_with_green_tips
# Processing Image - 350 in yellow_with_green_tips
# Processing Image - 351 in yellow_with_green_tips
# Processing Image - 352 in yellow_with_green_tips
# Processing Image - 353 in yellow_with_green_tips
# Processing Image - 354 in yellow_with_green_tips
# Processing Image - 355 in yellow_with_green_tips
# Processing Image - 356 in yellow_with_green_tips
# Processing Image - 357 in yellow_with_green_tips
# Processing Image - 358 in yellow_with_green_tips
# Processing Image - 359 in yellow_with_green_tips
# Processing Image - 360 in yellow_with_green_tips
# Processing Image - 361 in yellow_with_green_tips
# Processing Image - 362 in yellow_with_green_tips
# Processing Image - 363 in yellow_with_green_tips
# Processing Image - 364 in yellow_with_green_tips
# Processing Image - 365 in yellow_with_green_tips
# Processing Image - 366 in yellow_with_green_tips
# Processing Image - 367 in yellow_with_green_tips
# Processing Image - 368 in yellow_with_green_tips
# Processing Image - 369 in yellow_with_green_tips
# Processing Image - 370 in yellow_with_green_tips
# Processing Image - 371 in yellow_with_green_tips
# Processing Image - 372 in yellow_with_green_tips
# Processing Image - 373 in yellow_with_green_tips
# Processing Image - 374 in yellow_with_green_tips
# Processing Image - 375 in yellow_with_green_tips
# Processing Image - 376 in yellow_with_green_tips
# Processing Image - 377 in yellow_with_green_tips
# Processing Image - 378 in yellow_with_green_tips
# Processing Image - 379 in yellow_with_green_tips
# Processing Image - 380 in yellow_with_green_tips
# Processing Image - 381 in yellow_with_green_tips
# Processing Image - 382 in yellow_with_green_tips
# Processing Image - 383 in yellow_with_green_tips
# Processing Image - 384 in yellow_with_green_tips
# Processing Image - 385 in yellow_with_green_tips
# Processing Image - 386 in yellow_with_green_tips
# Processing Image - 387 in yellow_with_green_tips
# Processing Image - 388 in yellow_with_green_tips
# Processing Image - 389 in yellow_with_green_tips
# Processing Image - 390 in yellow_with_green_tips
# Processing Image - 391 in yellow_with_green_tips
# Processing Image - 392 in yellow_with_green_tips
# Processing Image - 393 in yellow_with_green_tips
# Processing Image - 394 in yellow_with_green_tips
# Processing Image - 395 in yellow_with_green_tips
# Processing Image - 396 in yellow_with_green_tips
# Processing Image - 397 in yellow_with_green_tips
# Processing Image - 398 in yellow_with_green_tips
# Processing Image - 399 in yellow_with_green_tips
# Processing Image - 400 in yellow_with_green_tips
# Processing Image - 401 in yellow_with_green_tips
# Processing Image - 402 in yellow_with_green_tips
# Processing Image - 403 in yellow_with_green_tips
# Processing Image - 404 in yellow_with_green_tips
# Processing Image - 405 in yellow_with_green_tips
# Processing Image - 406 in yellow_with_green_tips

# %% [markdown]
# # **Building the dataset**

# %%
# get the overall feature vector size
print("[STATUS] textural feature vector size {}".format(np.array(textural_features).shape))
# Out:
# [STATUS] textural feature vector size (1242, 13)

# %%
# get the overall training label size
print("[STATUS] training Labels {}".format(np.array(textural_features_labels).shape))
# Out:
# [STATUS] training Labels (1242,)

# %%
# encode the target labels
def replace(my_list, my_dict):
    return [x if x not in my_dict else my_dict[x] for x in my_list]

labels_dict = {'totally_green': 0, 'yellow_with_green_tips': 1, 'yellow_with_brown_spots': 2}
target = replace(textural_features_labels, labels_dict)

print("[STATUS] training labels encoded...")
# Out:
# [STATUS] training labels encoded...

# %%
# scale features in the range (0-1)
scaler            = MinMaxScaler(feature_range=(0, 1))
rescaled_features = scaler.fit_transform(textural_features)
print("[STATUS] feature vector normalized...")
print("[STATUS] target labels: {}".format(np.array(target)))
print("[STATUS] target labels shape: {}".format(np.array(target).shape))
# Out:
# [STATUS] feature vector normalized...
# [STATUS] target labels: [0 0 0 ... 1 1 1]
# [STATUS] target labels shape: (1242,)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File('/home/operador2020/AI_bases_framework/textural_features.h5', 'w')
h5f_data.create_dataset('Banana_Ripeness_Textural_Features', data=np.array(rescaled_features))

h5f_label = h5py.File('/home/operador2020/AI_bases_framework/textural_features_labels.h5', 'w')
h5f_label.create_dataset('Banana_Ripeness_Textural_Features_Labels', data=np.array(target))

h5f_data.close()
h5f_label.close()

print("[STATUS] end of training..")
# Out:
# [STATUS] end of training..
